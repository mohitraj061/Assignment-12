# %% [raw]
# Ques 1.) In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened ?
#
# Solution :
#
# In Python's PyPDF2 library, the PdfFileReader() and PdfFileWriter() functions are used to read from and write to PDF files,
# respectively. When creating instances of these classes, we need to specify the mode in which the file objects will be opened.
#
# For PdfFileReader(),we should open the PDF file in the 'rb' mode, which stands for "read binary." This mode is used for
# reading files that contain binary data, such as PDF files. Opening the file in binary mode ensures that the PDF file is read
# correctly.
#
# Example :
#
# from PyPDF2 import PdfFileReader
#
# # Open the PDF file in read binary mode
# pdf_file = open('example.pdf', 'rb')
#
# # Create a PdfFileReader object using the opened file
# pdf_reader = PdfFileReader(pdf_file)
#
# # Perform operations with the PdfFileReader object
#
# # Close the opened file
# pdf_file.close()
#
#
# For PdfFileWriter(), we should open the PDF file in the 'wb' mode, which stands for "write binary." This mode is used for
# writing binary data to files, such as when we are creating a new PDF or modifying an existing one.
#
# Example :
#
# from PyPDF2 import PdfFileWriter
#
# # Open a PDF file in write binary mode
# pdf_file = open('output.pdf', 'wb')
#
# # Create a PdfFileWriter object
# pdf_writer = PdfFileWriter()
#
# # Perform operations with the PdfFileWriter object
#
# # Write the modified PDF to the opened file
# pdf_writer.write(pdf_file)
#
# # Close the opened file
# pdf_file.close()
#
#
# Remember to close the file objects using the close() method when we are done working with them to free up system resources and
# ensure that any changes are properly saved.

# %% [raw]
# Ques 2.) From a PdfFileReader object, how do you get a Page object for page 5 ?
#
# Solution :
#
# To get a Page object for a specific page from a PdfFileReader object in PyPDF2, we can use the getPage() method and pass the
# page number as an argument. It's important to note that page numbering in PyPDF2 starts from 0, so the first page would be
# page 0, the second page would be page 1, and so on.
#
# Here's an example of how to get a Page object for page 5 (which corresponds to page number 4 in PyPDF2) :
#
# from PyPDF2 import PdfFileReader
#
# # Open the PDF file in read binary mode
# pdf_file = open('example.pdf', 'rb')
#
# # Create a PdfFileReader object using the opened file
# pdf_reader = PdfFileReader(pdf_file)
#
# # Get the Page object for page 5 (page number 4 in PyPDF2)
# page = pdf_reader.getPage(4)
#
# # Perform operations with the Page object
#
# # Close the opened file
# pdf_file.close()
#
# In the example above, the getPage(4) method is used to retrieve the Page object for the fifth page of the PDF file. Remember to
# adjust the page number accordingly if we are interested in a different page.

# %% [raw]
# 3. What PdfFileReader variable stores the number of pages in the PDF document ?
#
# Solution :
#
# The PdfFileReader class in PyPDF2 has a property called numPages that stores the number of pages in the PDF document. We can
# access this property to retrieve the total number of pages in the PDF.
#
# Here's an example of how to use the numPages property :
#
# from PyPDF2 import PdfFileReader
#
# # Open the PDF file in read binary mode
# pdf_file = open('example.pdf', 'rb')
#
# # Create a PdfFileReader object using the opened file
# pdf_reader = PdfFileReader(pdf_file)
#
# # Get the number of pages in the PDF
# num_pages = pdf_reader.numPages
#
# # Print the total number of pages
# print("Total number of pages:", num_pages)
#
# # Close the opened file
# pdf_file.close()
#
# In the example above, the numPages property is accessed on the pdf_reader object to retrieve the total number of pages in the
# PDF. The value is then stored in the num_pages variable and printed to the console. Remember to adjust the filename and path as
# necessary to match our specific PDF file.

# %% [raw]
# Ques 4.) If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page
#          objects from it ?
#
# Solution :
#
# If a PdfFileReader object's PDF is encrypted with a password, such as "swordfish", we need to provide the password to decrypt
# the PDF before we can obtain Page objects from it. To do this, we can use the decrypt() method of the PdfFileReader object,
# passing the password as the argument.
#
# Here's an example of how to decrypt an encrypted PDF with a password before obtaining Page objects :
#
# from PyPDF2 import PdfFileReader
#
# # Open the encrypted PDF file in read binary mode
# pdf_file = open('encrypted.pdf', 'rb')
#
# # Create a PdfFileReader object using the opened file
# pdf_reader = PdfFileReader(pdf_file)
#
# # Decrypt the PDF with the password
# pdf_reader.decrypt('swordfish')
#
# # Get the Page object for a specific page
# page = pdf_reader.getPage(0)  # Assuming you want the first page
#
# # Perform operations with the Page object
#
# # Close the opened file
# pdf_file.close()
#
# In the example above, the decrypt('swordfish') method is used to decrypt the PDF with the password "swordfish" before retrieving
# the Page object. Adjust the filename and path according to our specific encrypted PDF file.
#
# After decrypting the PDF, we can use methods like getPage() or iterate over the pages to obtain Page objects and perform
# operations on them as needed.

# %% [raw]
# Ques 5.) What methods do you use to rotate a page ?
#
# Solution :
#
# To rotate a page in PyPDF2, we can use the rotateClockwise() or rotateCounterClockwise() methods available on the Page object.
# These methods allow us to rotate a page by a specified angle.
#
# Here's an example that demonstrates how to rotate a page clockwise by 90 degrees using the rotateClockwise() method :
#
# from PyPDF2 import PdfFileReader, PdfFileWriter
#
# # Open the PDF file in read binary mode
# pdf_file = open('example.pdf', 'rb')
#
# # Create a PdfFileReader object using the opened file
# pdf_reader = PdfFileReader(pdf_file)
#
# # Create a PdfFileWriter object
# pdf_writer = PdfFileWriter()
#
# # Get the Page object for the desired page (e.g., page 5)
# page = pdf_reader.getPage(4)
#
# # Rotate the page clockwise by 90 degrees
# page.rotateClockwise(90)
#
# # Add the modified page to the PdfFileWriter
# pdf_writer.addPage(page)
#
# # Save the modified PDF to a new file
# output_file = open('output.pdf', 'wb')
# pdf_writer.write(output_file)
# output_file.close()
#
# # Close the opened file
# pdf_file.close()
#
# In the example above, we open an existing PDF file, create a PdfFileReader object, and a PdfFileWriter object. We retrieve the
# desired page (e.g., page 5) using getPage(), rotate it clockwise by 90 degrees using rotateClockwise(), and add the modified
# page to the PdfFileWriter object. Finally, we save the modified PDF to a new file named "output.pdf".
#
# We can also use the rotateCounterClockwise() method to rotate a page counterclockwise by a specified angle. Just replace
# rotateClockwise() with rotateCounterClockwise() in the example above to rotate the page counterclockwise.
#
# Remember to adjust the filenames and paths according to our specific files.

# %% [raw]
# Ques 6.) What is the difference between a Run object and a Paragraph object ?
#
# Solution :
#
# In the context of document processing, a "Run" and a "Paragraph" are typically associated with structured text documents, such
# as those created with word processing software. The specific definitions and distinctions can vary depending on the document
# processing library or framework being used. However, in general, the terms can be understood as follows :
#
# 1.) Run :
#
# * A "Run" refers to a contiguous sequence of characters or formatting within a paragraph.
# * It represents a span of text that shares the same formatting attributes, such as font style, size, color, or other properties.
# * Runs are commonly used to apply specific formatting changes, such as bold, italics, underline, or different text colors,
#   within a paragraph.
# * Runs can also represent different types of content within a paragraph, such as hyperlinks or special symbols.
# * In some document processing libraries, such as Python's python-docx library, a "Run" object represents a single run of text
#   with specific formatting properties.
#
# 2.) Paragraph :
#
# * A "Paragraph" refers to a block of text that is treated as a unit of content.
# * It represents a collection of one or more lines of text that are logically grouped together.
# * Paragraphs are used to structure and organize the content within a document, often with distinct formatting, spacing, or
#   alignment.
# * They are typically separated by line breaks or empty lines.
# * In document processing libraries, a "Paragraph" object may provide methods or properties to manipulate or access the text and
#   formatting of the entire paragraph as a whole.
#
# To summarize, a "Run" represents a specific span of formatted text within a paragraph, whereas a "Paragraph" represents a block
# of text as a unit of content with potentially different formatting or structure compared to other paragraphs in the document.
# The exact functionality and available features of Run and Paragraph objects may vary depending on the specific library or
# framework being used for document processing.

# %% [raw]
# Ques 7.) How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc ?
#
# Solution :
#
# To obtain a list of Paragraph objects for a Document object stored in a variable named doc, we can use the paragraphs property
# of the Document object. The paragraphs property returns a list of all the paragraphs in the document.
#
# Here's an example of how to access the list of Paragraph objects :
#
# from docx import Document
#
# # Assuming we have a Document object stored in the variable 'doc'
#
# # Get the list of Paragraph objects
# paragraphs = doc.paragraphs
#
# # Iterate over the paragraphs and perform operations
# for paragraph in paragraphs:
#     # Perform operations on each Paragraph object
#     print(paragraph.text)  # Example : Print the text of each paragraph
#
# In the example above, the paragraphs property is used to obtain the list of Paragraph objects from the Document object stored
# in the variable doc. Then, the code iterates over each Paragraph object in the list and performs operations on it. In this
# example, it prints the text of each paragraph using the text property of the Paragraph object.
#
# Remember to adjust the code according to our specific use case and the document processing library we are using.

# %% [raw]
# Ques 8.) What type of object has bold, underline, italic, strike, and outline variables ?
#
# Solution :
#
# The type of object that typically has attributes or variables such as bold, underline, italic, strike, and outline is a "Run"
# object in document processing libraries.
#
# In libraries like python-docx, a "Run" object represents a span of text with specific formatting properties within a paragraph.
# These formatting properties include attributes like bold, underline, italic, strike, and outline. By modifying these attributes
# of a Run object, we can apply formatting changes to the corresponding span of text within a paragraph.
#
# Here's an example demonstrating the usage of these attributes in a Run object using python-docx :
#
# from docx import Document
#
# # Create a new document
# doc = Document()
#
# # Add a paragraph with formatted text
# paragraph = doc.add_paragraph()
# run = paragraph.add_run("This is some sample text.")
#
# # Apply formatting attributes to the Run object
# run.bold = True
# run.underline = True
# run.italic = True
# run.strike = True
# run.outline = True
#
# # Save the document
# doc.save("formatted.docx")
#
# In the example above, a new document is created, and a paragraph with some text is added. The text is assigned to a Run object
# named run. The formatting attributes like bold, underline, italic, strike, and outline are then set to True on the Run object
# to apply the respective formatting to the text. Finally, the document is saved as "formatted.docx".
#
# Remember that the availability and naming of these attributes may vary depending on the document processing library or
# framework we are using.

# %% [raw]
# Ques 9.) What is the difference between False, True, and None for the bold variable ?
#
# Solution :
#
# In the context of document processing libraries, such as python-docx, the values False, True, and None for the bold variable
# represent different states or settings for the bold formatting attribute of a text run. Here's the difference between these
# values :
#
# 1.) False :
#
#     * Setting the bold attribute to False means that the text run is not formatted as bold.
#     * The text will be displayed in the default or regular font weight.
#
# 2.) True :
#
#     * Setting the bold attribute to True means that the text run is formatted as bold.
#     * The text will be displayed in a bold or heavier font weight.
#
# 3.) None :
#
#     * Assigning None to the bold attribute indicates that the bold formatting is neither explicitly enabled nor disabled for
#       the text run.
#     * The text will be displayed with the default formatting, which could be bold or regular based on the surrounding context
#       or the document's default styles.
#
# It's important to note that the exact behavior of these values may depend on the specific document processing library or
# framework we are using. While python-docx follows the conventions described above, other libraries or frameworks might have
# slightly different implementations or interpretations.
#
# Here's an example demonstrating the usage of these values with the bold attribute in a Run object using python-docx :
#
# from docx import Document
#
# doc = Document()
# paragraph = doc.add_paragraph()
# run = paragraph.add_run("This is some sample text.")
#
# run.bold = False  # Text is not bold
# run.text = "Regular text"  # Overriding the text with new content
#
# run.bold = True  # Text is bold
# run.text = "Bold text"  # Overriding the text with new content
#
# run.bold = None  # Use default formatting for bold
#
# doc.save("formatted.docx")
#
# In the example above, the bold attribute of the Run object is set to False to make the text regular, then set to True to make
# it bold, and finally set to None to use the default formatting. The text attribute of the Run object is updated to reflect the
# changes in the text content.
#
# Remember to refer to the documentation of the specific document processing library we are using for precise details about the
# behavior and usage of these attributes.

# %% [raw]
# Ques 10.) How do you create a Document object for a new Word document ?
#
# Solution :
#
# To create a Document object for a new Word document using the python-docx library, we can simply call the Document() constructor
# without any arguments. This will create an empty Document object representing a new, blank Word document.
#
# Here's an example :
#
# from docx import Document
#
# # Create a new Word document
# doc = Document()
#
# # Perform operations on the Document object
# # Add paragraphs, tables, formatting, etc.
#
# # Save the document
# doc.save('new_document.docx')
#
# In the example above, we import the Document class from the docx module. Then, we create a new Document object by calling the
# Document() constructor. This creates an empty Word document. We can perform various operations on the doc object, such as
# adding paragraphs, tables, applying formatting, and more.
#
# Finally, the save() method is used to save the document to a specific file. In the example, the document is saved as
# "new_document.docx" in the current working directory. Adjust the filename and path as needed.
#
# By following this approach, we can create a Document object for a new Word document and subsequently work with it to populate
# the document with content and formatting using the python-docx library.

# %% [raw]
# Ques 11.) How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc ?
#
# Solution :
#
# To add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc using the python-docx
# library, we can use the add_paragraph() method of the Document object. Here's an example :
#
# from docx import Document
#
# # Assuming we have a Document object stored in the variable 'doc'
#
# # Add a paragraph with the text 'Hello, there!'
# paragraph = doc.add_paragraph('Hello, there!')
#
# # Save the document
# doc.save('document_with_paragraph.docx')
#
# In the example above, the add_paragraph() method is used to add a new paragraph to the Document object doc with the text
# 'Hello, there!'. The returned Paragraph object (stored in the paragraph variable) represents the newly added paragraph.
#
# After adding the paragraph, we can continue to work with the Document object, adding more paragraphs, applying formatting,
# adding tables, or performing other operations as needed. Finally, the document can be saved using the save() method.
#
# Adjust the filename and path in the doc.save() line to specify the desired location and name for the saved document.
#
# By following this approach, we can add paragraphs with specific text to a Document object and customize the content of the
# Word document using python-docx.

# %% [raw]
# Ques 12.) What integers represent the levels of headings available in Word documents ?
#
# Solution :
#
# In Word documents, heading levels are typically represented using integer values. The specific integer values assigned to each
# heading level may vary depending on the document processing library or framework being used. However, in the widely used
# Heading styles in Word, the levels are typically represented as follows :
#
# 1.) Heading 1 : Level 1
# 2.) Heading 2 : Level 2
# 3.) Heading 3 : Level 3
# 4.) Heading 4 : Level 4
# 5.) Heading 5 : Level 5
# 6.) Heading 6 : Level 6
# 7.) Heading 7 : Level 7
# 8.) Heading 8 : Level 8
# 9.) Heading 9 : Level 9
#
# In Word processing libraries like python-docx, we can typically apply these heading levels using the add_heading() method of
# the Document object and specifying the desired level using the level parameter.
#
# Here's an example :
#
# from docx import Document
#
# doc = Document()
#
# # Add a Heading 1
# doc.add_heading('Heading 1 Text', level=1)
#
# # Add a Heading 2
# doc.add_heading('Heading 2 Text', level=2)
#
# # Add a Heading 3
# doc.add_heading('Heading 3 Text', level=3)
#
# # Save the document
# doc.save('document_with_headings.docx')
#
# In the example above, the add_heading() method is used to add headings with different levels (1, 2, and 3) to the Document
# object doc. The level parameter is set accordingly to specify the desired heading level.
#
# Adjust the text and levels according to our requirements and continue adding headings or performing other operations on the
# Document object as needed.
#
# Remember that the specific integer values or the available heading styles may differ depending on the document processing
# library or framework we are using.
